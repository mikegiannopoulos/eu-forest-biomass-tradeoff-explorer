# %% [markdown]
# # EU Forest Biomass Trade-off Explorer
#
# This notebook is a lightweight presentation layer over the processed outputs generated by the pipeline.

# %%
from pathlib import Path
import pandas as pd

project_root = Path.cwd().resolve()
if not (project_root / 'outputs').exists():
    project_root = project_root.parent
summary = pd.read_csv(project_root / 'outputs' / 'scenario_summary_eu.csv')
best = pd.read_csv(project_root / 'outputs' / 'best_scenario_by_country.csv')
ranking = pd.read_csv(project_root / 'outputs' / 'country_ranking_table.csv')

summary

# %%
best['scenario_label'].value_counts()

# %%
ranking.head(10)
